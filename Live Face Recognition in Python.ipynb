# %%
import threading
import cv2
from deepface import DeepFace

# %%
cap = cv2.VideoCapture(0, cv2.CAP_DSHOW)
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)
# Out:
# True

# %%
counter = 0
face_match = False
reference_img = cv2.imread("bb.jpg")

def check_face(frame):
    global face_match
    try:
        if DeepFace.verify(frame, reference_img.copy())['verified']:
            face_match = True
        else:
            face_match = False
    except ValueError:
        face_match = False
    
while True:
    ret, frame = cap.read()
    if ret:
        if counter % 30 == 0:
            try:
                threading.Thread(target=check_face, args=(frame.copy(),)).start()
            except ValueError:
                 pass
        counter += 1
        if face_match:
            cv2.putText(frame, "MATCH!", (20, 450), cv2.FONT_HERSHEY_SIMPLEX, 2, (0, 255, 0), 3)
          
        else:
            cv2.putText(frame, "NO MATCH!", (20, 450), cv2.FONT_HERSHEY_SIMPLEX, 2, (0, 0, 255), 3)
        cv2.imshow("video", frame)
    key = cv2.waitKey(1)
    if key == ord("q"):
        break
cv2.destroyAllWindows()
# Out:
# vgg_face_weights.h5 will be downloaded...
# vgg_face_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/vgg_face_weights.h5
# To: C:\Users\FUJITSU\.deepface\weights\vgg_face_weights.h5
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/vgg_face_weights.h5
# To: C:\Users\FUJITSU\.deepface\weights\vgg_face_weights.h5
#   0%|                                                                                       | 0.00/580M [00:00<?, ?B/s]
#   0%|                                                                                | 524k/580M [00:03<57:25, 168kB/s]
#   0%|                                                                                | 524k/580M [00:03<58:07, 166kB/s]
# vgg_face_weights.h5 will be downloaded...
#   0%|▏                                                                              | 1.05M/580M [00:04<42:49, 225kB/s]
#   0%|▏                                                                              | 1.57M/580M [00:04<24:08, 399kB/s]
#   1%|▌                                                                              | 4.19M/580M [00:06<09:56, 965kB/s]
#   0%|▎                                                                              | 2.10M/580M [00:06<26:09, 368kB/s]Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/vgg_face_weights.h5
# To: C:\Users\FUJITSU\.deepface\weights\vgg_face_weights.h5
#   1%|▋                                                                             | 4.72M/580M [00:06<08:00, 1.20MB/s]
#
#   1%|▊                                                                             | 6.29M/580M [00:08<08:11, 1.17MB/s]
#
#   1%|█                                                                             | 7.86M/580M [00:08<05:14, 1.82MB/s]
#
#   2%|█▏                                                                            | 8.91M/580M [00:09<04:55, 1.93MB/s]
#
#   2%|█▎                                                                            | 9.44M/580M [00:09<04:19, 2.20MB/s]
#   2%|█▎                                                                            | 9.96M/580M [00:09<04:14, 2.24MB/s]
#
#   2%|█▌                                                                            | 11.5M/580M [00:10<03:35, 2.64MB/s]
#
#   2%|█▋                                                                            | 12.6M/580M [00:10<03:30, 2.70MB/s]
#   2%|█▊                                                                             | 13.6M/580M [00:12<11:08, 847kB/s]
#
#   1%|▍                                                                              | 3.15M/580M [00:05<20:35, 467kB/s]
#   2%|█▉                                                                             | 14.2M/580M [00:12<09:34, 985kB/s]
#
#   3%|██                                                                            | 15.7M/580M [00:13<05:06, 1.84MB/s]
#
#   1%|▋                                                                             | 5.24M/580M [00:06<07:42, 1.24MB/s]
#   3%|██▏                                                                           | 16.3M/580M [00:13<05:22, 1.75MB/s]
#
#   1%|▊                                                                             | 5.77M/580M [00:06<07:18, 1.31MB/s]
#
#   3%|██▎                                                                           | 16.8M/580M [00:13<05:48, 1.62MB/s]
#   1%|▋                                                                              | 4.72M/580M [00:14<25:04, 383kB/s]
#
#   3%|██▎                                                                           | 17.3M/580M [00:14<07:58, 1.18MB/s]
#
#   3%|██▍                                                                           | 18.4M/580M [00:15<06:28, 1.45MB/s]
#   1%|▋                                                                              | 5.24M/580M [00:15<20:11, 475kB/s]
#
#   3%|██▌                                                                           | 18.9M/580M [00:15<07:59, 1.17MB/s]
#   3%|██▋                                                                           | 19.9M/580M [00:16<05:24, 1.72MB/s]
#
#   2%|█▎                                                                            | 9.44M/580M [00:09<05:59, 1.59MB/s]
#   4%|██▋                                                                           | 20.4M/580M [00:16<06:47, 1.37MB/s]
#
#   2%|█▎                                                                            | 9.96M/580M [00:09<07:25, 1.28MB/s]
#   4%|██▉                                                                           | 21.5M/580M [00:17<06:01, 1.54MB/s]
#
#   2%|█▍                                                                            | 11.0M/580M [00:10<06:20, 1.50MB/s]
#
#   2%|█▌                                                                            | 11.5M/580M [00:10<05:23, 1.76MB/s]
#   4%|███                                                                           | 22.5M/580M [00:17<05:05, 1.82MB/s]
#
#   2%|█▌                                                                            | 12.1M/580M [00:11<06:29, 1.46MB/s]
#   4%|███                                                                           | 23.1M/580M [00:18<05:36, 1.65MB/s]
#
#   4%|███▏                                                                          | 23.6M/580M [00:18<05:43, 1.62MB/s]
#
#   2%|█▊                                                                            | 13.1M/580M [00:11<05:55, 1.59MB/s]
#   4%|███▏                                                                          | 24.1M/580M [00:18<05:54, 1.57MB/s]
#
#   2%|█▊                                                                            | 13.6M/580M [00:11<05:55, 1.59MB/s]
#   2%|█▏                                                                             | 8.91M/580M [00:18<10:05, 944kB/s]
# vgg_face_weights.h5 will be downloaded...
#   4%|███▎                                                                          | 24.6M/580M [00:19<06:03, 1.53MB/s]
#
#   2%|█▉                                                                            | 14.2M/580M [00:12<06:17, 1.50MB/s]
#   2%|█▎                                                                             | 9.44M/580M [00:19<09:40, 983kB/s]
#
#   4%|███▍                                                                          | 25.7M/580M [00:19<06:08, 1.50MB/s]
#   2%|█▎                                                                             | 9.96M/580M [00:19<09:44, 976kB/s]
#
#   5%|███▌                                                                          | 26.2M/580M [00:20<06:11, 1.49MB/s]
#
#   3%|██                                                                            | 15.7M/580M [00:13<07:00, 1.34MB/s]
#   5%|███▌                                                                          | 26.7M/580M [00:20<06:23, 1.44MB/s]
#
#   5%|███▋                                                                           | 27.3M/580M [00:22<12:18, 748kB/s]
#   5%|███▊                                                                           | 27.8M/580M [00:22<10:21, 888kB/s]
#
#   3%|██▎                                                                            | 16.8M/580M [00:15<12:06, 775kB/s]Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/vgg_face_weights.h5
# To: C:\Users\FUJITSU\.deepface\weights\vgg_face_weights.h5
# vgg_face_weights.h5 will be downloaded...
#   0%|                                                                                       | 0.00/580M [00:00<?, ?B/s]
#   2%|█▌                                                                             | 11.5M/580M [00:22<13:35, 697kB/s]
#
#   5%|███▊                                                                           | 28.3M/580M [00:22<09:40, 950kB/s]
#   2%|█▋                                                                             | 12.1M/580M [00:23<13:01, 727kB/s]
#
#
#   5%|███▉                                                                          | 28.8M/580M [00:23<08:54, 1.03MB/s]
#
#   3%|██▍                                                                            | 17.8M/580M [00:16<09:48, 955kB/s]Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/vgg_face_weights.h5
# To: C:\Users\FUJITSU\.deepface\weights\vgg_face_weights.h5
#
#
#
#
#   5%|███▉                                                                          | 29.4M/580M [00:23<08:39, 1.06MB/s]
#
#   3%|██▍                                                                            | 18.4M/580M [00:17<09:39, 969kB/s]
#   2%|█▋                                                                             | 12.6M/580M [00:23<12:44, 742kB/s]
#
#
#   0%|▏                                                                              | 1.05M/580M [00:01<14:47, 652kB/s]
#
#
#
#   5%|████                                                                          | 29.9M/580M [00:24<08:55, 1.03MB/s]
#
#   3%|██▌                                                                            | 18.9M/580M [00:17<10:01, 932kB/s]
#   2%|█▊                                                                             | 13.1M/580M [00:24<13:24, 704kB/s]
#
#
#
#   5%|████▏                                                                          | 30.4M/580M [00:25<09:45, 939kB/s]
#
#   3%|██▋                                                                            | 19.4M/580M [00:18<10:42, 873kB/s]
#
#
#   0%|▏                                                                              | 1.57M/580M [00:02<16:49, 573kB/s]
#
#
#
#   5%|████▏                                                                          | 30.9M/580M [00:25<09:46, 936kB/s]
#   2%|█▊                                                                             | 13.6M/580M [00:25<13:31, 698kB/s]
#
#
#
#   5%|████▎                                                                          | 31.5M/580M [00:26<09:21, 978kB/s]
#
#
#
#   0%|▎                                                                             | 2.62M/580M [00:02<08:26, 1.14MB/s]
#
#   3%|██▋                                                                            | 19.9M/580M [00:19<13:01, 717kB/s]
#
#
#   0%|▎                                                                              | 2.10M/580M [00:03<18:28, 521kB/s]
#   6%|████▎                                                                         | 32.0M/580M [00:26<09:04, 1.01MB/s]
#
#
#
#   1%|▍                                                                             | 3.15M/580M [00:03<08:01, 1.20MB/s]
#
#
#
#   6%|████▎                                                                         | 32.5M/580M [00:26<08:38, 1.06MB/s]
#
#
#
#   1%|▌                                                                              | 4.19M/580M [00:04<11:13, 855kB/s]
#
#   4%|██▊                                                                            | 20.4M/580M [00:21<18:35, 502kB/s]
#   3%|█▉                                                                             | 14.7M/580M [00:28<18:24, 512kB/s]
#
#
#   6%|████▍                                                                          | 33.0M/580M [00:28<12:09, 750kB/s]
#
#
#
#   6%|████▌                                                                          | 33.6M/580M [00:28<12:22, 736kB/s]
#
#
#
#   1%|▋                                                                              | 5.24M/580M [00:05<10:05, 949kB/s]
#   3%|██                                                                             | 15.2M/580M [00:29<22:10, 425kB/s]
#
#
#
#   6%|████▋                                                                          | 34.1M/580M [00:30<14:41, 620kB/s]
#
#
#   1%|▍                                                                              | 3.15M/580M [00:07<27:42, 347kB/s]
#
#   4%|██▊                                                                            | 21.0M/580M [00:23<24:06, 387kB/s]
#
#
#
#   6%|████▋                                                                          | 34.6M/580M [00:30<12:36, 721kB/s]
#
#
#
#   1%|▉                                                                             | 6.82M/580M [00:07<09:19, 1.02MB/s]
#   3%|██▏                                                                            | 15.7M/580M [00:30<20:58, 449kB/s]
#
#
#
#   6%|████▊                                                                          | 35.1M/580M [00:30<11:16, 805kB/s]
#
#
#   1%|▍                                                                              | 3.67M/580M [00:08<24:48, 387kB/s]
#
#   4%|██▉                                                                            | 21.5M/580M [00:24<24:24, 382kB/s]
#
#
#
#   6%|████▊                                                                          | 35.7M/580M [00:31<11:37, 780kB/s]
#   6%|████▉                                                                          | 36.2M/580M [00:32<11:51, 764kB/s]
#
#
#
#   1%|█▏                                                                             | 8.39M/580M [00:09<11:58, 796kB/s]
#
#
#   1%|▌                                                                              | 4.19M/580M [00:10<25:58, 370kB/s]
#
#
#
#   6%|████▉                                                                          | 36.7M/580M [00:33<11:23, 795kB/s]
#
#
#
#   6%|█████                                                                          | 37.2M/580M [00:33<10:13, 885kB/s]
#
#   4%|██▉                                                                            | 22.0M/580M [00:26<27:41, 336kB/s]
#
#
#
#   2%|█▍                                                                            | 10.5M/580M [00:10<07:19, 1.29MB/s]
#
#
#   1%|▋                                                                              | 4.72M/580M [00:11<23:47, 403kB/s]
#   7%|█████▏                                                                         | 37.7M/580M [00:33<09:39, 936kB/s]
#
#
#
#   2%|█▍                                                                            | 11.0M/580M [00:10<07:30, 1.26MB/s]
#   7%|█████▏                                                                         | 38.3M/580M [00:34<10:24, 867kB/s]
#
#
#
#   2%|█▌                                                                            | 11.5M/580M [00:11<08:01, 1.18MB/s]
#
#
#   1%|▋                                                                              | 5.24M/580M [00:12<21:59, 436kB/s]
#
#   4%|███                                                                            | 22.5M/580M [00:28<28:08, 330kB/s]
#   3%|██▍                                                                            | 17.8M/580M [00:35<18:46, 499kB/s]
#
#
#
#   7%|█████▎                                                                         | 38.8M/580M [00:35<11:49, 762kB/s]
#
#
#   1%|▊                                                                              | 5.77M/580M [00:13<20:30, 467kB/s]
#
#
#
#   2%|█▋                                                                             | 12.6M/580M [00:12<09:34, 988kB/s]
#   7%|█████▎                                                                         | 39.3M/580M [00:36<11:28, 785kB/s]
#
#   4%|███▏                                                                           | 23.1M/580M [00:29<25:33, 363kB/s]
#
#
#   1%|▊                                                                              | 6.29M/580M [00:13<18:03, 530kB/s]
#
#
#
#   7%|█████▍                                                                         | 39.8M/580M [00:36<10:54, 825kB/s]
#
#
#
#   2%|█▊                                                                            | 13.6M/580M [00:13<09:22, 1.01MB/s]
#
#
#   1%|▉                                                                              | 6.82M/580M [00:14<16:17, 586kB/s]
#
#   4%|███▏                                                                           | 23.6M/580M [00:30<23:17, 398kB/s]
#   7%|█████▍                                                                         | 40.4M/580M [00:37<11:04, 812kB/s]
#
#
#
#   2%|█▉                                                                             | 14.2M/580M [00:14<10:10, 927kB/s]
#
#
#   7%|█████▌                                                                         | 40.9M/580M [00:37<10:49, 830kB/s]
#
#   4%|███▎                                                                           | 24.1M/580M [00:31<21:19, 434kB/s]
#
#
#   1%|█                                                                              | 7.86M/580M [00:15<14:20, 665kB/s]
#
#
#
#   7%|█████▋                                                                         | 41.4M/580M [00:38<10:36, 847kB/s]
#   7%|█████▋                                                                         | 41.9M/580M [00:39<10:23, 863kB/s]
#
#   4%|███▎                                                                           | 24.6M/580M [00:32<19:52, 466kB/s]
#
#
#   1%|█▏                                                                             | 8.39M/580M [00:16<14:56, 638kB/s]
#
#
#
#   3%|██                                                                             | 15.2M/580M [00:15<13:16, 709kB/s]
#   7%|█████▊                                                                         | 42.5M/580M [00:39<10:23, 862kB/s]
#
#   4%|███▍                                                                           | 25.2M/580M [00:33<18:54, 489kB/s]
#
#
#   2%|█▏                                                                             | 8.91M/580M [00:17<15:04, 632kB/s]
#
#
#
#   7%|█████▊                                                                         | 43.0M/580M [00:40<10:35, 845kB/s]
#   4%|██▊                                                                            | 20.4M/580M [00:40<18:46, 497kB/s]
#
#
#   2%|█▎                                                                             | 9.44M/580M [00:18<15:35, 610kB/s]
#
#
#
#   3%|██▏                                                                            | 16.3M/580M [00:17<14:22, 654kB/s]
#
#   8%|█████▉                                                                         | 43.5M/580M [00:41<11:46, 759kB/s]
#
#
#
#   3%|██▎                                                                            | 16.8M/580M [00:18<13:35, 690kB/s]
#
#
#   2%|█▎                                                                             | 9.96M/580M [00:19<14:38, 649kB/s]
#   8%|█████▉                                                                         | 44.0M/580M [00:41<11:41, 764kB/s]
#
#   5%|███▌                                                                           | 26.2M/580M [00:35<18:17, 505kB/s]
#
#
#
#   3%|██▎                                                                            | 17.3M/580M [00:18<12:55, 726kB/s]
#
#
#   8%|██████                                                                         | 44.6M/580M [00:42<11:21, 786kB/s]
#   4%|██▉                                                                            | 21.5M/580M [00:42<18:33, 502kB/s]
#
#   5%|███▋                                                                           | 26.7M/580M [00:36<17:13, 535kB/s]
#
#
#
#   3%|██▍                                                                            | 17.8M/580M [00:19<12:23, 756kB/s]
#
#
#   8%|██████▏                                                                        | 45.1M/580M [00:43<11:43, 761kB/s]
#
#
#
#   3%|██▍                                                                            | 18.4M/580M [00:20<12:13, 766kB/s]
#   4%|██▉                                                                            | 22.0M/580M [00:43<18:25, 505kB/s]
#
#
#   2%|█▌                                                                             | 11.5M/580M [00:21<13:07, 722kB/s]
#
#   8%|██████▏                                                                        | 45.6M/580M [00:44<15:51, 562kB/s]
#
#
#   2%|█▋                                                                             | 12.1M/580M [00:22<17:40, 535kB/s]
#   4%|███                                                                            | 22.5M/580M [00:45<21:48, 426kB/s]
#
#
#
#   8%|██████▎                                                                        | 46.1M/580M [00:45<14:57, 595kB/s]
#
#   5%|███▊                                                                           | 27.8M/580M [00:39<22:22, 411kB/s]
#
#
#   2%|█▋                                                                             | 12.6M/580M [00:23<15:19, 617kB/s]
#   4%|███▏                                                                           | 23.1M/580M [00:45<18:03, 514kB/s]
#
#
#
#   8%|██████▎                                                                        | 46.7M/580M [00:46<13:11, 674kB/s]
#
#
#   2%|█▊                                                                             | 13.1M/580M [00:23<13:16, 712kB/s]
#   4%|███▏                                                                           | 23.6M/580M [00:46<15:12, 610kB/s]
#
#
#
#   8%|██████▍                                                                        | 47.2M/580M [00:46<11:41, 760kB/s]
#   4%|███▎                                                                           | 24.1M/580M [00:47<13:59, 662kB/s]
#
#
#
#   4%|██▊                                                                            | 20.4M/580M [00:23<12:37, 739kB/s]
#
#
#   8%|██████▍                                                                        | 47.7M/580M [00:47<12:00, 739kB/s]
#
#   5%|███▊                                                                           | 28.3M/580M [00:40<23:28, 392kB/s]
#
#
#
#   4%|██▊                                                                            | 21.0M/580M [00:24<12:29, 746kB/s]
#   4%|███▎                                                                           | 24.6M/580M [00:47<13:27, 688kB/s]
#
#
#   8%|██████▌                                                                        | 48.2M/580M [00:48<16:28, 538kB/s]
#
#
#   3%|█▉                                                                             | 14.7M/580M [00:26<15:32, 606kB/s]
#   4%|███▍                                                                           | 25.2M/580M [00:49<17:57, 515kB/s]
#
#
#
#   8%|██████▋                                                                        | 48.8M/580M [00:49<14:24, 615kB/s]
#   4%|███▍                                                                           | 25.7M/580M [00:50<15:54, 581kB/s]
#
#
#
#   8%|██████▋                                                                        | 49.3M/580M [00:50<13:21, 662kB/s]
#
#
#   3%|██                                                                             | 15.2M/580M [00:27<15:14, 618kB/s]
#
#
#
#   4%|███                                                                            | 22.5M/580M [00:26<13:31, 687kB/s]
#   9%|██████▊                                                                        | 49.8M/580M [00:50<11:58, 738kB/s]
#
#
#   3%|██▏                                                                            | 15.7M/580M [00:28<14:41, 640kB/s]
#
#
#
#   4%|███▏                                                                           | 23.1M/580M [00:27<12:17, 755kB/s]
